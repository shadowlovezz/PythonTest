# %% [markdown]
# # Python爬虫三大库之Lxml
#
#
# ## 实验目的
# 了解Lxml库在网页解析方面的应用。
#
#
# ## 实验要求
# 掌握Lxml库在网页解析方面的应用。

# %% [markdown]
# ## 实验原理
#
# Lxml是另一种高效的网页解析库。Lxml是Python语言中和XML以及HTML工作的功能中最丰富和最容易使用的库。它是另一个Python爬虫的常用库，是基于libxml2这一XML解析库的Python封装，速度比BeatifulSoup快。
#
# lxml支持HTML和XML的解析，支持XPath解析方式，而且解析效率非常高。
#
# XPath，全称XML Path Language，即XML路径语言，它是一门在XML文档中查找信息的语言，它最初是用来搜寻XML文档的，但是它同样适用于HTML文档的搜索
#
# XPath的选择功能十分强大，它提供了非常简明的路径选择表达式，另外，它还提供了超过100个内建函数，用于字符串、数值、时间的匹配以及节点、序列的处理等，几乎所有我们想要定位的节点，都可以用XPath来选择

# %% [markdown]
# ## 实验步骤
#
# 首先通过一个简单的例子了解一下Lxml库是如何解析如下text字符串中的HTML文档。
# ```
# text = """
#   <title>The Dormouse's story</title>
#   <p class="title" name="dromouse"><b>The Dormouse's story</b></p>
#   <p class="story">Once upon a time there were three little sisters; and their names were
#   <a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
#   <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
#   <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
#   and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  """
# ```
# 程序示例如下：
#
# ![image.png](attachment:image.png)
#
# - 请输入上述代码并运行

# %% [markdown]
# - 结果如下
#
# ![image.png](attachment:image.png)
#
# 由上面程序的运行结果，出乎预料的是Lxml并没有格式化输出HTML文档，不过，它自动补齐了text中缺少的HTML标签。

# %% [markdown]
# 我们可以使用decode()函数来完成格式化输出，示例代码如下：
#
# ![image.png](attachment:image.png)
#
# - 请输入上述代码并运行

# %% [markdown]
# - 结果如下
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 接下来，我们学习Lxml库中的标签搜索方法，在Lxml库中可用find()、findall()及xpath()3中方式搜索Element包含的标签对象，其区别如下。
#
# ① find(): 返回第一个匹配对象，其参数使用的XPath语言只能用相对路径(以‘//’开头)。
#
# ② findall(): 返回一个标签对象的列表，其参数使用的XPath语法只能用相对路径(以".//"开头)。
#
# ③ xpath()： 返回一个标签对象的列表，其参数使用的XPath语法既可以是相对路径，也可以是绝对路径，示例程序如下：
#
# ![image.png](attachment:image.png)
#
# - 请输入上述代码并运行

# %% [markdown]
# - 结果如下
#
# ![image.png](attachment:image.png)
#
# find(): 返回目标标签第一个位置，而且必须用相对路径，不然提示语法错误。

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 请输入上述代码并运行

# %% [markdown]
# - 结果如下
#
# ![image.png](attachment:image.png)
#
# findall():与xpath()的检索结果一致，只是findall()中必须使用相对路径，而xpath()两种路径格式均可。

# %% [markdown]
# ### 实验结束后
#
# ![image.png](attachment:image.png)
